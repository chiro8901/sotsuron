# %%
import pandas as pd
import numpy as np
import pickle

# %%
with open("C:\Users\chiro\titech\programming_python\exp_pro\data\data_words.pkl", "rb") as f:
    data = pickle.load(f)

print(data)
# Out:
#   Cell In[4], line 1
#     with open("C:\Users\chiro\titech\programming_python\exp_pro\data\data_words.pkl", "rb") as f:
#               ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
